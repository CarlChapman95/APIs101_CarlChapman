# %%
import pandas as pd
import requests

# %%
response = requests.get('https://randomfox.ca/floof')
print(response.status_code)
print(response.text)
print(response.json())

fox = response.json()
print(fox['image'])
# Out:
# 200
# {"image":"https:\/\/randomfox.ca\/images\/10.jpg","link":"https:\/\/randomfox.ca\/?i=10"}
# {'image': 'https://randomfox.ca/images/10.jpg', 'link': 'https://randomfox.ca/?i=10'}
# https://randomfox.ca/images/10.jpg
